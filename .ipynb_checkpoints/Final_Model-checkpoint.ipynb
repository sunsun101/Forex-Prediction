# %%
import pandas as pd
import numpy as np

# %%
# !pip install pytorch_forecasting
# !pip install pytorch_lightning
# Out:
# Requirement already satisfied: pytorch_forecasting in /home/st122283/.local/lib/python3.8/site-packages (0.10.1)
# Requirement already satisfied: pandas<2.0.0,>=1.3.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_forecasting) (1.4.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.8/dist-packages (from pytorch_forecasting) (3.5.1)
# Requirement already satisfied: optuna<3.0.0,>=2.3.0 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_forecasting) (2.10.0)
# Requirement already satisfied: pytorch-lightning<2.0.0,>=1.2.4 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_forecasting) (1.6.3)
# Requirement already satisfied: torch<2.0,>=1.7 in /usr/local/lib/python3.8/dist-packages (from pytorch_forecasting) (1.11.0)
# Requirement already satisfied: statsmodels in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_forecasting) (0.13.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.8/dist-packages (from pytorch_forecasting) (1.8.0)
# Requirement already satisfied: scikit-learn<1.1,>=0.24 in /usr/local/lib/python3.8/dist-packages (from pytorch_forecasting) (1.0.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.3.0->pytorch_forecasting) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.3.0->pytorch_forecasting) (2022.1)
# Requirement already satisfied: numpy>=1.18.5; platform_machine != "aarch64" and platform_machine != "arm64" and python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from pandas<2.0.0,>=1.3.0->pytorch_forecasting) (1.22.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pytorch_forecasting) (9.1.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pytorch_forecasting) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pytorch_forecasting) (1.4.2)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pytorch_forecasting) (4.31.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pytorch_forecasting) (21.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.8/dist-packages (from matplotlib->pytorch_forecasting) (0.11.0)
# Requirement already satisfied: colorlog in /home/st122283/.local/lib/python3.8/site-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (6.6.0)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.8/dist-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (6.0)
# Requirement already satisfied: tqdm in /home/st122283/.local/lib/python3.8/site-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (4.63.0)
# Requirement already satisfied: cliff in /home/st122283/.local/lib/python3.8/site-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (3.10.1)
# Requirement already satisfied: sqlalchemy>=1.1.0 in /home/st122283/.local/lib/python3.8/site-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.4.36)
# Requirement already satisfied: alembic in /home/st122283/.local/lib/python3.8/site-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.7.7)
# Requirement already satisfied: cmaes>=0.8.2 in /home/st122283/.local/lib/python3.8/site-packages (from optuna<3.0.0,>=2.3.0->pytorch_forecasting) (0.8.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2022.3.0)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.3.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (4.1.1)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.8.0)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.8.1)
# Requirement already satisfied: patsy>=0.5.2 in /home/st122283/.local/lib/python3.8/site-packages (from statsmodels->pytorch_forecasting) (0.5.2)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.8/dist-packages (from scikit-learn<1.1,>=0.24->pytorch_forecasting) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from scikit-learn<1.1,>=0.24->pytorch_forecasting) (3.1.0)
# Requirement already satisfied: six>=1.5 in /usr/lib/python3/dist-packages (from python-dateutil>=2.8.1->pandas<2.0.0,>=1.3.0->pytorch_forecasting) (1.14.0)
# Requirement already satisfied: stevedore>=2.0.1 in /home/st122283/.local/lib/python3.8/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (3.5.0)
# Requirement already satisfied: autopage>=0.4.0 in /home/st122283/.local/lib/python3.8/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (0.5.0)
# Requirement already satisfied: pbr!=2.1.0,>=2.0.0 in /home/st122283/.local/lib/python3.8/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (5.8.1)
# Requirement already satisfied: PrettyTable>=0.7.2 in /home/st122283/.local/lib/python3.8/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (3.2.0)
# Requirement already satisfied: cmd2>=1.0.0 in /home/st122283/.local/lib/python3.8/site-packages (from cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (2.4.1)
# Requirement already satisfied: greenlet!=0.4.17; python_version >= "3" and (platform_machine == "aarch64" or (platform_machine == "ppc64le" or (platform_machine == "x86_64" or (platform_machine == "amd64" or (platform_machine == "AMD64" or (platform_machine == "win32" or platform_machine == "WIN32")))))) in /home/st122283/.local/lib/python3.8/site-packages (from sqlalchemy>=1.1.0->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.1.2)
# Requirement already satisfied: importlib-metadata; python_version < "3.9" in /usr/local/lib/python3.8/dist-packages (from alembic->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (4.11.3)
# Requirement already satisfied: Mako in /home/st122283/.local/lib/python3.8/site-packages (from alembic->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.2.0)
# Requirement already satisfied: importlib-resources; python_version < "3.9" in /home/st122283/.local/lib/python3.8/site-packages (from alembic->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (5.7.1)
# Requirement already satisfied: requests; extra == "http" in /usr/lib/python3/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.22.0)
# Requirement already satisfied: aiohttp; extra == "http" in /home/st122283/.local/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (3.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.4.6)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (3.20.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.6.2)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.44.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.6.1)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (45.2.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (3.3.6)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.34.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.1.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.8.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.0.0)
# Requirement already satisfied: wcwidth in /home/st122283/.local/lib/python3.8/site-packages (from PrettyTable>=0.7.2->cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (0.2.5)
# Requirement already satisfied: attrs>=16.3.0 in /home/st122283/.local/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (21.4.0)
# Requirement already satisfied: pyperclip>=1.6 in /home/st122283/.local/lib/python3.8/site-packages (from cmd2>=1.0.0->cliff->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (1.8.2)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata; python_version < "3.9"->alembic->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (3.8.0)
# Requirement already satisfied: MarkupSafe>=0.9.2 in /home/st122283/.local/lib/python3.8/site-packages (from Mako->alembic->optuna<3.0.0,>=2.3.0->pytorch_forecasting) (2.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.7.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (6.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.3.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.0.12)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (4.0.2)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (1.3.1)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (4.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.2.8)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (2.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (3.2.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.8/dist-packages (from rsa<5,>=3.1.4; python_version >= "3.6"->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning<2.0.0,>=1.2.4->pytorch_forecasting) (0.4.8)
# Requirement already satisfied: pytorch_lightning in /home/st122283/.local/lib/python3.8/site-packages (1.6.3)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_lightning) (0.8.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_lightning) (2022.3.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (21.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (4.1.1)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_lightning) (0.3.2)
# Requirement already satisfied: tensorboard>=2.2.0 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (2.8.0)
# Requirement already satisfied: torch>=1.8.* in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.11.0)
# Requirement already satisfied: PyYAML>=5.4 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.8/dist-packages (from pytorch_lightning) (1.22.3)
# Requirement already satisfied: tqdm>=4.57.0 in /home/st122283/.local/lib/python3.8/site-packages (from pytorch_lightning) (4.63.0)
# Requirement already satisfied: aiohttp; extra == "http" in /home/st122283/.local/lib/python3.8/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (3.8.1)
# Requirement already satisfied: requests; extra == "http" in /usr/lib/python3/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.22.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.8/dist-packages (from packaging>=17.0->pytorch_lightning) (3.0.7)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.0.0)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.44.0)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/lib/python3/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (45.2.0)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (2.1.1)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /usr/lib/python3/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.34.2)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.3.6)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (1.8.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (2.6.2)
# Requirement already satisfied: protobuf>=3.6.0 in /usr/local/lib/python3.8/dist-packages (from tensorboard>=2.2.0->pytorch_lightning) (3.20.0)
# Requirement already satisfied: attrs>=17.3.0 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (6.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.0.12)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.3.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.7.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (4.0.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/st122283/.local/lib/python3.8/site-packages (from aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (1.2.0)
# Requirement already satisfied: six in /usr/lib/python3/dist-packages (from absl-py>=0.4->tensorboard>=2.2.0->pytorch_lightning) (1.14.0)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /usr/local/lib/python3.8/dist-packages (from markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (4.11.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.8/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (1.3.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (5.0.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /usr/local/lib/python3.8/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (4.8)
# Requirement already satisfied: idna>=2.0 in /usr/lib/python3/dist-packages (from yarl<2.0,>=1.0->aiohttp; extra == "http"->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch_lightning) (2.8)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.8/dist-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard>=2.2.0->pytorch_lightning) (3.8.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.8/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch_lightning) (3.2.0)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.8/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch_lightning) (0.4.8)

# %%
import os 
import warnings

warnings.filterwarnings("ignore")

# %%
import torch
torch.cuda.is_available()
import pandas as pd

# %% [markdown]
# ### Importing Forex Dataset

# %%
data = pd.read_csv('dataset/final_data.csv', delimiter=",")

# %%
# Defining the time_index column
data = data.rename(columns={'Unnamed: 0': 'time_idx'})

# %%
data
# Out:
#        time_idx                 DATE     OPEN     HIGH      LOW    CLOSE  \
# 0             0  2012-04-09 00:00:00  1.30961  1.30965  1.30662  1.30687
# 1             1  2012-04-09 01:00:00  1.30688  1.30861  1.30668  1.30847
# 2             2  2012-04-09 02:00:00  1.30848  1.30876  1.30441  1.30443
# 3             3  2012-04-09 03:00:00  1.30444  1.30524  1.30330  1.30508
# 4             4  2012-04-09 04:00:00  1.30509  1.30618  1.30504  1.30581
# ...         ...                  ...      ...      ...      ...      ...
# 61997     61997  2022-04-08 14:00:00  1.08861  1.08881  1.08592  1.08638
# 61998     61998  2022-04-08 15:00:00  1.08637  1.08660  1.08504  1.08531
# 61999     61999  2022-04-08 16:00:00  1.08531  1.08581  1.08364  1.08399
# 62000     62000  2022-04-08 17:00:00  1.08399  1.08804  1.08388  1.08727
# 62001     62001  2022-04-08 18:00:00  1.08725  1.08815  1.08716  1.08757
#
#        TICKVOL  VOL  SPREAD 10-Year_Note_Auction  ...  \
# 0         2151    0      13                    -  ...
# 1         1490    0      12                    -  ...
# 2         2226    0      12                    -  ...
# 3         2322    0      13                    -  ...
# 4         1379    0      12                    -  ...
# ...        ...  ...     ...                  ...  ...
# 61997     3897    0       0                    -  ...
# 61998     4443    0       0                    -  ...
# 61999     6250    0       0                    -  ...
# 62000     6825    0       0                    -  ...
# 62001     2771    0       0                    -  ...
#
#       United_States_Treasury_Secretary_Yellen_Speech  \
# 0                                                  -
# 1                                                  -
# 2                                                  -
# 3                                                  -
# 4                                                  -
# ...                                              ...
# 61997                                              -
# 61998                                              -
# 61999                                              -
# 62000                                              -
# 62001                                              -
#
#       United_States_Treasury_Secretary_Yellen_Testimony  \
# 0                                                     -
# 1                                                     -
# 2                                                     -
# 3                                                     -
# 4                                                     -
# ...                                                 ...
# 61997                                                 -
# 61998                                                 -
# 61999                                                 -
# 62000                                                 -
# 62001                                                 -
#
#       United_States_Unemployment_Rate United_States_Unit_Labour_Costs_QoQ  \
# 0                                   -                                   -
# 1                                   -                                   -
# 2                                   -                                   -
# 3                                   -                                   -
# 4                                   -                                   -
# ...                               ...                                 ...
# 61997                               -                                   -
# 61998                               -                                   -
# 61999                               -                                   -
# 62000                               -                                   -
# 62001                               -                                   -
#
#       United_States_Wholesale_Inventories_MoM WASDE_Report Wages_in_euro_zone  \
# 0                                           -            -                  -
# 1                                           -            -                  -
# 2                                           -            -                  -
# 3                                           -            -                  -
# 4                                           -            -                  -
# ...                                       ...          ...                ...
# 61997                                       -            -                  -
# 61998                                       -            -                  -
# 61999                                       -            -                  -
# 62000                                       -            -                  -
# 62001                                       -            -                  -
#
#       World_Economic_Forum_Annual_Meetings ZEW_Economic_Sentiment  \
# 0                                        -                      -
# 1                                        -                      -
# 2                                        -                      -
# 3                                        -                      -
# 4                                        -                      -
# ...                                    ...                    ...
# 61997                                    -                      -
# 61998                                    -                      -
# 61999                                    -                      -
# 62000                                    -                      -
# 62001                                    -                      -
#
#       procure_ch_PMI
# 0                  -
# 1                  -
# 2                  -
# 3                  -
# 4                  -
# ...              ...
# 61997              -
# 61998              -
# 61999              -
# 62000              -
# 62001              -
#
# [62002 rows x 566 columns]

# %%
data.columns
# Out:
# Index(['time_idx', 'DATE', 'OPEN', 'HIGH', 'LOW', 'CLOSE', 'TICKVOL', 'VOL',
#        'SPREAD', '10-Year_Note_Auction',
#        ...
#        'United_States_Treasury_Secretary_Yellen_Speech',
#        'United_States_Treasury_Secretary_Yellen_Testimony',
#        'United_States_Unemployment_Rate',
#        'United_States_Unit_Labour_Costs_QoQ',
#        'United_States_Wholesale_Inventories_MoM', 'WASDE_Report',
#        'Wages_in_euro_zone', 'World_Economic_Forum_Annual_Meetings',
#        'ZEW_Economic_Sentiment', 'procure_ch_PMI'],
#       dtype='object', length=566)

# %%
special_days = data.columns[9:].tolist()
print(len(special_days))
# Out:
# 557

# %%
data = data.fillna('-', axis = 1)

# %%
# Replacing the 1s in all the special_days columns with respective names. (For proper categorical values)
data[special_days] = data[special_days].apply(lambda x: x.map({"1" : x.name})).astype("category")

# %%
data = data.fillna('-', axis = 1)

# %%
data.head()
# Out:
#   time_idx                 DATE     OPEN     HIGH      LOW    CLOSE TICKVOL  \
# 0        0  2012-04-09 00:00:00  1.30961  1.30965  1.30662  1.30687    2151
# 1        1  2012-04-09 01:00:00  1.30688  1.30861  1.30668  1.30847    1490
# 2        2  2012-04-09 02:00:00  1.30848  1.30876  1.30441  1.30443    2226
# 3        3  2012-04-09 03:00:00  1.30444  1.30524   1.3033  1.30508    2322
# 4        4  2012-04-09 04:00:00  1.30509  1.30618  1.30504  1.30581    1379
#
#   VOL SPREAD 10-Year_Note_Auction  ...  \
# 0   0     13                    -  ...
# 1   0     12                    -  ...
# 2   0     12                    -  ...
# 3   0     13                    -  ...
# 4   0     12                    -  ...
#
#   United_States_Treasury_Secretary_Yellen_Speech  \
# 0                                              -
# 1                                              -
# 2                                              -
# 3                                              -
# 4                                              -
#
#   United_States_Treasury_Secretary_Yellen_Testimony  \
# 0                                                 -
# 1                                                 -
# 2                                                 -
# 3                                                 -
# 4                                                 -
#
#   United_States_Unemployment_Rate United_States_Unit_Labour_Costs_QoQ  \
# 0                               -                                   -
# 1                               -                                   -
# 2                               -                                   -
# 3                               -                                   -
# 4                               -                                   -
#
#   United_States_Wholesale_Inventories_MoM WASDE_Report Wages_in_euro_zone  \
# 0                                       -            -                  -
# 1                                       -            -                  -
# 2                                       -            -                  -
# 3                                       -            -                  -
# 4                                       -            -                  -
#
#   World_Economic_Forum_Annual_Meetings ZEW_Economic_Sentiment procure_ch_PMI
# 0                                    -                      -              -
# 1                                    -                      -              -
# 2                                    -                      -              -
# 3                                    -                      -              -
# 4                                    -                      -              -
#
# [5 rows x 566 columns]

# %%
data[data['10-Year_Note_Auction'] == '10-Year_Note_Auction'].head()
# Out:
#      time_idx                 DATE     OPEN     HIGH      LOW    CLOSE  \
# 60         60  2012-04-11 12:00:00  1.31377  1.31564  1.31322  1.31436
# 540       540  2012-05-09 12:00:00  1.29753  1.29841  1.29651  1.29757
# 1140     1140  2012-06-13 12:00:00  1.25454  1.25524  1.25315  1.25318
# 1620     1620  2012-07-11 12:00:00  1.22759  1.22939  1.22714  1.22867
# 2100     2100  2012-08-08 12:00:00   1.2361  1.23691  1.23451  1.23542
#
#      TICKVOL VOL SPREAD  10-Year_Note_Auction  ...  \
# 60      4461   0      6  10-Year_Note_Auction  ...
# 540     4273   0      5  10-Year_Note_Auction  ...
# 1140    4757   0      5  10-Year_Note_Auction  ...
# 1620    3462   0      5  10-Year_Note_Auction  ...
# 2100    4552   0      5  10-Year_Note_Auction  ...
#
#      United_States_Treasury_Secretary_Yellen_Speech  \
# 60                                                -
# 540                                               -
# 1140                                              -
# 1620                                              -
# 2100                                              -
#
#      United_States_Treasury_Secretary_Yellen_Testimony  \
# 60                                                   -
# 540                                                  -
# 1140                                                 -
# 1620                                                 -
# 2100                                                 -
#
#      United_States_Unemployment_Rate United_States_Unit_Labour_Costs_QoQ  \
# 60                                 -                                   -
# 540                                -                                   -
# 1140                               -                                   -
# 1620                               -                                   -
# 2100                               -                                   -
#
#      United_States_Wholesale_Inventories_MoM WASDE_Report Wages_in_euro_zone  \
# 60                                         -            -                  -
# 540                                        -            -                  -
# 1140                                       -            -                  -
# 1620                                       -            -                  -
# 2100                                       -            -                  -
#
#      World_Economic_Forum_Annual_Meetings ZEW_Economic_Sentiment  \
# 60                                      -                      -
# 540                                     -                      -
# 1140                                    -                      -
# 1620                                    -                      -
# 2100                                    -                      -
#
#      procure_ch_PMI
# 60                -
# 540               -
# 1140              -
# 1620              -
# 2100              -
#
# [5 rows x 566 columns]

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
data['CLOSE'].astype(float).plot()
plt.legend()
plt.xticks(rotation = 70);

# %%
import time
import datetime

# %%
 data['DATE'] = pd.to_datetime(data['DATE'])

# %%
# Creating 1s of shape (len_data).  (We  only have one group (EUR_USD))
grp = pd.Series(np.ones((len(data))))

# %%
data['grp'] = grp

# %%
# Creating new copy of dataset
new_df = data.copy()

# %%
# Naming each day from DATE column (Sunday, Monday, Tuesday, Wednesday, Thursday, Friday)
new_df['day_of_week'] = new_df['DATE'].map(lambda x: x.day_name()).astype("category")

# %%
new_df[['DATE', 'day_of_week']]
# Out:
#                      DATE day_of_week
# 0     2012-04-09 00:00:00      Monday
# 1     2012-04-09 01:00:00      Monday
# 2     2012-04-09 02:00:00      Monday
# 3     2012-04-09 03:00:00      Monday
# 4     2012-04-09 04:00:00      Monday
# ...                   ...         ...
# 61997 2022-04-08 14:00:00      Friday
# 61998 2022-04-08 15:00:00      Friday
# 61999 2022-04-08 16:00:00      Friday
# 62000 2022-04-08 17:00:00      Friday
# 62001 2022-04-08 18:00:00      Friday
#
# [62002 rows x 2 columns]

# %%
new_df["month"] = new_df['DATE'].dt.month.astype(str).astype("category")
new_df["year"] = new_df['DATE'].dt.year.astype(str).astype("category")
new_df['year'] = new_df["year"].astype(int)
new_df['month'] = new_df["month"].astype(int)

# %%
# Converting columns to proper datatypes
new_df['OPEN'] = new_df["OPEN"].astype(float)
new_df['HIGH'] = new_df["HIGH"].astype(float)
new_df['CLOSE'] = new_df["CLOSE"].astype(float)
new_df['LOW'] = new_df["LOW"].astype(float)
new_df['TICKVOL'] = new_df["TICKVOL"].astype(float)
new_df['VOL'] = new_df["VOL"].astype(float)
new_df['SPREAD'] = new_df["SPREAD"].astype(int)

# %%
 new_df['time_idx'] = new_df['time_idx'].astype(int)

# %%
 new_df['grp'] = new_df['grp'].astype("str")

# %%
# for col in special_days:
#     new_df[col] = new_df[col].astype('category')

# %%
new_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62002 entries, 0 to 62001
# Columns: 570 entries, time_idx to year
# dtypes: category(1), datetime64[ns](1), float64(6), int32(4), object(558)
# memory usage: 268.3+ MB

# %%
import copy
from pathlib import Path
import numpy as np
import pandas as pd

import pytorch_lightning as pl
from pytorch_lightning.callbacks import EarlyStopping, LearningRateMonitor
from pytorch_lightning.loggers import TensorBoardLogger

import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer, TimeSeriesDataSet
from pytorch_forecasting.data import GroupNormalizer
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# %% [markdown]
# ### Create TimeSeries Dataset from our custom dataset

# %%
from pytorch_forecasting.data.timeseries import TimeSeriesDataSet

max_encoder_length = 720 # As our data is in hours of each day (24hrs * 30) Sequence of 1 month for history
max_prediction_length =  720 #Same for prediction
training_cutoff = new_df["time_idx"].max() - max_prediction_length
    
timeseries = TimeSeriesDataSet(
     new_df,
    time_idx = "time_idx", 
    target = 'CLOSE',
    group_ids = ['grp'],
    min_encoder_length= max_encoder_length // 2,  # keep encoder length long (as it is in the validation set)
    max_encoder_length=max_encoder_length,
    min_prediction_length=1,
    max_prediction_length=max_prediction_length,
    static_categoricals=["grp"],
    add_relative_time_idx=False,
    time_varying_known_reals=["time_idx", "OPEN", "HIGH", "LOW", "TICKVOL", "VOL"],
    target_normalizer=GroupNormalizer(
        groups=["grp"], transformation="softplus"
    ),
    variable_groups={"special_days": special_days}, 
    time_varying_known_categoricals=["special_days", "day_of_week"],
    time_varying_unknown_categoricals=[], 
    add_target_scales=True, 
    add_encoder_length=True,
    time_varying_unknown_reals = ['CLOSE'],
    allow_missing_timesteps=True)

# %%
timeseries.get_parameters()
# Out:
# {'time_idx': 'time_idx',
#  'target': 'CLOSE',
#  'group_ids': ['grp'],
#  'weight': None,
#  'max_encoder_length': 25,
#  'min_encoder_length': 12,
#  'min_prediction_idx': 0,
#  'min_prediction_length': 1,
#  'max_prediction_length': 50,
#  'static_categoricals': ['grp'],
#  'static_reals': ['encoder_length', 'CLOSE_center', 'CLOSE_scale'],
#  'time_varying_known_categoricals': ['special_days', 'day_of_week'],
#  'time_varying_known_reals': ['time_idx',
#   'OPEN',
#   'HIGH',
#   'LOW',
#   'TICKVOL',
#   'VOL'],
#  'time_varying_unknown_categoricals': [],
#  'time_varying_unknown_reals': ['CLOSE'],
#  'variable_groups': {'special_days': ['10-Year_Note_Auction',
#    'ADP_Nonfarm_Employment_Change',
#    'API_Weekly_Crude_Oil_Stock',
#    'API_Weekly_Cushing_Crude_Oil_Stock',
#    'Austria_Bank_Austria_Manufacturing_PMI',
#    'Austria_Retail_Sales_MoM',
#    'Austria_Retail_Sales_YoY',
#    'Austria_Unemployment_Rate',
#    'Average_Hourly_Earnings',
#    'Average_Hourly_Earnings_YoY',
#    'Beige_Book',
#    'Belgium_Extraordinary_NATO_Summit',
#    'Belgium_NATO_Defence_Ministers_Meeting',
#    'Belgium_NATO_Summit',
#    'Building_Permits',
#    'Business_Inventories',
#    'CB_Consumer_Confidence',
#    'CFTC_Crude_Oil_speculative_net_positions',
#    'CFTC_EUR_speculative_net_positions',
#    'CFTC_Gold_speculative_net_positions',
#    'CFTC_Nasdaq_100_speculative_net_positions',
#    'CFTC_Nasdaq_100_speculative_positions',
#    'CFTC_Samp;P_500_speculative_net_positions',
#    'CPI',
#    'Cap_Goods_Ship_Non_Defense_Ex_Air',
#    'Chicago_PMI',
#    'Core_CPI',
#    'Core_Durable_Goods_Orders',
#    'Core_PCE_Price_Index',
#    'Core_PPI',
#    'Core_Retail_Sales',
#    'Crude_Oil_Inventories',
#    'Current_Account',
#    'Cushing_Crude_Oil_Inventories',
#    'Cyprus_GDP_Growth_Rate_QoQ',
#    'Deposit_Facility_Rate',
#    'Durable_Goods_Orders',
#    'ECB39;s_Coeure_Speaks',
#    'ECB39;s_Constancio_Speaks',
#    'ECB39;s_Costa_Speaks',
#    'ECB39;s_De_Guindos_Speaks',
#    'ECB39;s_Enria_Speaks',
#    'ECB39;s_Lane_Speaks',
#    'ECB39;s_Lautenschlaeger_Speaks',
#    'ECB39;s_Liikanen_Speaks',
#    'ECB39;s_Mersch_Speaks',
#    'ECB39;s_Nowotny_Speaks',
#    'ECB39;s_Panetta_Speaks',
#    'ECB39;s_Praet_Speaks',
#    'ECB39;s_Schnabel_Speaks',
#    'ECB_Economic_Bulletin',
#    'ECB_Financial_Stability_Review',
#    'ECB_Hakkarainen_Speaks',
#    'ECB_Interest_Rate_Decision',
#    'ECB_LTRO',
#    'ECB_Marginal_Lending_Facility',
#    'ECB_McCaul_Speaks',
#    'ECB_Monetary_Policy_Statement',
#    'ECB_President_Draghi_Speaks',
#    'ECB_President_Lagarde_Speaks',
#    'ECB_President_Trichet_Speaks',
#    'ECB_Press_Conference',
#    'ECB_Publishes_Account_of_Monetary_Policy_Meeting',
#    'EIA_Short-Term_Energy_Outlook',
#    'EU_Barnier_Speaks',
#    'EU_Economic_Forecasts',
#    'EU_Finance_Ministers_Meeting',
#    'EU_Leaders_Summit',
#    'Employment_Cost_Index',
#    'Employment_Level',
#    'Euro_Area_Balance_of_Trade',
#    'Euro_Area_CPI',
#    'Euro_Area_Construction_Output_YoY',
#    'Euro_Area_Consumer_Confidence',
#    'Euro_Area_Core_Inflation_Rate_YoY',
#    'Euro_Area_Deposit_Facility_Rate',
#    'Euro_Area_ECB_Annual_Report',
#    'Euro_Area_ECB_De_Guindos_Speech',
#    'Euro_Area_ECB_Economic_Bulletin',
#    'Euro_Area_ECB_Elderson_Speech',
#    'Euro_Area_ECB_Enria_Speech',
#    'Euro_Area_ECB_Fernandez-Bollo_Speech',
#    'Euro_Area_ECB_Financial_Stability_Review',
#    'Euro_Area_ECB_Forum_on_Central_Banking',
#    'Euro_Area_ECB_General_Council_Meeting',
#    'Euro_Area_ECB_Guindos_Speech',
#    'Euro_Area_ECB_Interest_Rate_Decision',
#    'Euro_Area_ECB_Lane_Speech',
#    'Euro_Area_ECB_Macroeconomic_Projections',
#    'Euro_Area_ECB_Monetary_Policy_Meeting_Accounts',
#    'Euro_Area_ECB_Non-Monetary_Policy_Meeting',
#    'Euro_Area_ECB_Panetta_Speech',
#    'Euro_Area_ECB_President_Lagarde_Speech',
#    'Euro_Area_ECB_Press_Conference',
#    'Euro_Area_ECB_Schnabel_Speech',
#    'Euro_Area_Economic_Sentiment',
#    'Euro_Area_Employment_Change_QoQ',
#    'Euro_Area_Employment_Change_YoY',
#    'Euro_Area_Eurogroup_Meeting',
#    'Euro_Area_European_Commission_Spring_Forecasts',
#    'Euro_Area_GDP_Growth_Rate_QoQ',
#    'Euro_Area_GDP_Growth_Rate_YoY',
#    'Euro_Area_Government_Budget_to_GDP',
#    'Euro_Area_Government_Debt_to_GDP',
#    'Euro_Area_Industrial_Production_MoM',
#    'Euro_Area_Industrial_Production_YoY',
#    'Euro_Area_Inflation_Rate_MoM',
#    'Euro_Area_Inflation_Rate_YoY',
#    'Euro_Area_Marginal_Lending_Rate',
#    'Euro_Area_Markit_Composite_PMI',
#    'Euro_Area_Markit_Manufacturing_PMI',
#    'Euro_Area_Markit_Services_PMI',
#    'Euro_Area_Retail_Sales_MoM',
#    'Euro_Area_Retail_Sales_YoY',
#    'Euro_Area_SP_Global_Manufacturing_PMI',
#    'Euro_Area_SP_Global_Services_PMI',
#    'Euro_Area_Unemployment_Rate',
#    'Euro_Area_ZEW_Economic_Sentiment_Index',
#    'Euro_Summit',
#    'Eurogroup_Meetings',
#    'European_Parliament_Elections',
#    'European_Union_EcoFin_Meeting',
#    'European_Union_European_Commission_Forecasts',
#    'European_Union_European_Council_Meeting',
#    'European_Union_New_Car_Registrations_YoY',
#    'Existing_Home_Sales',
#    'Export_Price_Index',
#    'Exports',
#    'FOMC_Economic_Projections',
#    'FOMC_Meeting_Minutes',
#    'FOMC_Member_Bostic_Speaks',
#    'FOMC_Member_Bowman_Speaks',
#    'FOMC_Member_Brainard_Speaks',
#    'FOMC_Member_Bullard_Speaks',
#    'FOMC_Member_Clarida_Speaks',
#    'FOMC_Member_Daly_Speaks',
#    'FOMC_Member_Dudley_Speaks',
#    'FOMC_Member_Duke_Speaks',
#    'FOMC_Member_Fisher_Speaks',
#    'FOMC_Member_George_Speaks',
#    'FOMC_Member_Harker_Speaks',
#    'FOMC_Member_Kaplan_Speaks',
#    'FOMC_Member_Kashkari_Speaks',
#    'FOMC_Member_Kocherlakota_Speaks',
#    'FOMC_Member_Lacker_Speaks',
#    'FOMC_Member_Lockhart_Speaks',
#    'FOMC_Member_Mester_Speaks',
#    'FOMC_Member_Pianalto_Speaks',
#    'FOMC_Member_Plosser_Speaks',
#    'FOMC_Member_Powell_Speaks',
#    'FOMC_Member_Quarles_Speaks',
#    'FOMC_Member_Raskin_Speaks',
#    'FOMC_Member_Rosengren_Speaks',
#    'FOMC_Member_Stanley_Fischer_Speaks',
#    'FOMC_Member_Stein_Speaks',
#    'FOMC_Member_Tarullo_Speaks',
#    'FOMC_Member_Williams_Speaks',
#    'FOMC_Member_Yellen_Speaks',
#    'FOMC_Press_Conference',
#    'FOMC_Statement',
#    'Factory_Orders',
#    'Fed_Bank_Stress_Test_Results',
#    'Fed_Chair_Powell_Speaks',
#    'Fed_Chair_Powell_Testifies',
#    'Fed_Chair_Yellen_Speaks',
#    'Fed_Chair_Yellen_Testifies',
#    'Fed_Chairman_Bernanke_Speaks',
#    'Fed_Chairman_Bernanke_Testifies',
#    'Fed_Interest_Rate_Decision',
#    'Fed_Monetary_Policy_Report',
#    'Federal_Budget_Balance',
#    'France_Balance_of_Trade',
#    'France_Business_Confidence',
#    'France_Consumer_Confidence',
#    'France_GDP_Growth_Rate_QoQ',
#    'France_GDP_Growth_Rate_YoY',
#    'France_IEA_Oil_Market_Report',
#    'France_Industrial_Production_MoM',
#    'France_Inflation_Rate_MoM',
#    'France_Inflation_Rate_YoY',
#    'France_Jobseekers_Total',
#    'France_Markit_Composite_PMI',
#    'France_Markit_Manufacturing_PMI',
#    'France_Markit_Services_PMI',
#    'France_Presidential_Election_1st_Round',
#    'France_Presidential_Election_2nd_Round',
#    'France_Regional_Elections_-_1st_Round',
#    'France_Regional_Elections_-_2nd_Round',
#    'France_SP_Global_Manufacturing_PMI',
#    'France_SP_Global_Services_PMI',
#    'France_Unemployment_Benefit_Claims',
#    'France_Unemployment_Rate',
#    'French_CPI',
#    'French_Consumer_Spending',
#    'French_GDP',
#    'French_HICP',
#    'French_Manufacturing_PMI',
#    'French_Non-Farm_Payrolls',
#    'French_Services_PMI',
#    'GDP',
#    'GDP_Price_Index',
#    'German_10-Year_Bund_Auction',
#    'German_Buba_Beermann_Speaks',
#    'German_Buba_Mauderer_Speaks',
#    'German_Buba_President_Weidmann_Speaks',
#    'German_Buba_Vice_President_Buch_Speaks',
#    'German_Buba_Wuermeling_Speaks',
#    'German_Business_Expectations',
#    'German_CPI',
#    'German_Current_Assessment',
#    'German_Factory_Orders',
#    'German_Federal_Election',
#    'German_GDP',
#    'German_Ifo_Business_Climate_Index',
#    'German_Industrial_Production',
#    'German_Manufacturing_PMI',
#    'German_PPI',
#    'German_Retail_Sales',
#    'German_Services_PMI',
#    'German_Trade_Balance',
#    'German_Unemployment_Change',
#    'German_Unemployment_Rate',
#    'German_ZEW_Current_Conditions',
#    'German_ZEW_Economic_Sentiment',
#    'Germany_10-Year_Bund_Auction',
#    'Germany_Balance_of_Trade',
#    'Germany_Bundesbank_Balz_Speech',
#    'Germany_Bundesbank_Beermann_Speech',
#    'Germany_Bundesbank_Buch_Speech',
#    'Germany_Bundesbank_Mauderer_Speech',
#    'Germany_Bundesbank_Weidmann_Speech',
#    'Germany_Bundesbank_Wuermeling_Speech',
#    'Germany_Construction_PMI',
#    'Germany_Factory_Orders_MoM',
#    'Germany_Federal_Election',
#    'Germany_Full_Year_GDP_Growth',
#    'Germany_GDP_Growth_Rate_QoQ',
#    'Germany_GDP_Growth_Rate_YoY',
#    'Germany_GfK_Consumer_Confidence',
#    'Germany_Ifo_Business_Climate',
#    'Germany_Industrial_Production_MoM',
#    'Germany_Inflation_Rate_MoM',
#    'Germany_Inflation_Rate_YoY',
#    'Germany_Markit_Composite_PMI',
#    'Germany_Markit_Manufacturing_PMI',
#    'Germany_Markit_Services_PMI',
#    'Germany_PPI_MoM',
#    'Germany_Retail_Sales_MoM',
#    'Germany_Retail_Sales_YoY',
#    'Germany_SP_GlobalBME_Manufacturing_PMI',
#    'Germany_Unemployed_Persons',
#    'Germany_Unemployment_Change',
#    'Germany_Unemployment_Rate',
#    'Germany_Unemployment_Rate_Harmonised',
#    'Germany_Wholesale_Prices_MoM',
#    'Germany_Wholesale_Prices_YoY',
#    'Germany_ZEW_Economic_Sentiment_Index',
#    'GfK_German_Consumer_Climate',
#    'Goods_Trade_Balance',
#    'Greece_GDP_Growth_Rate_YoY',
#    'Greece_Markit_Manufacturing_PMI',
#    'Greece_Retail_Sales_YoY',
#    'Greece_Unemployment_Rate',
#    'Housing_Starts',
#    'IEA_Monthly_Report',
#    'IHS_Markit_Construction_PMI',
#    'ISM_Manufacturing_Employment',
#    'ISM_Manufacturing_PMI',
#    'ISM_Non-Manufacturing_Employment',
#    'ISM_Non-Manufacturing_PMI',
#    'Import_Price_Index',
#    'Imports',
#    'Industrial_New_Orders',
#    'Industrial_Production',
#    'Initial_Jobless_Claims',
#    'Interest_Rate_Projection_-_1st_Yr',
#    'Interest_Rate_Projection_-_2nd_Yr',
#    'Interest_Rate_Projection_-_3rd_Yr',
#    'Interest_Rate_Projection_-_Current',
#    'Interest_Rate_Projection_-_Longer',
#    'Investing_com_EURUSD_Index',
#    'Investing_com_Gold_Index',
#    'Investing_com_Samp;P_500_Index',
#    'Investing_com_USDCHF_Index',
#    'Ireland_GDP_Growth_Rate_QoQ',
#    'Ireland_Inflation_Rate_YoY',
#    'Italian_10-Year_BTP_Auction',
#    'Italian_CPI',
#    'Italian_Constitutional_Referendum',
#    'Italian_General_Election',
#    'Italian_Manufacturing_PMI',
#    'Italian_Services_PMI',
#    'Italy_10-Year_BTP_Auction',
#    'Italy_Balance_of_Trade',
#    'Italy_Business_Confidence',
#    'Italy_Consumer_Confidence',
#    'Italy_Full_Year_GDP_Growth',
#    'Italy_G20_Finance_and_Central_Bank_Deputies_Meeting',
#    'Italy_GDP_Growth_Rate_QoQ',
#    'Italy_GDP_Growth_Rate_YoY',
#    'Italy_Government_Budget',
#    'Italy_IHS_Markit_Composite_PMI',
#    'Italy_IHS_Markit_Manufacturing_PMI',
#    'Italy_IHS_Markit_Services_PMI',
#    'Italy_Industrial_Production_MoM',
#    'Italy_Inflation_Rate_MoM',
#    'Italy_Inflation_Rate_YoY',
#    'Italy_Retail_Sales_MoM',
#    'Italy_Retail_Sales_YoY',
#    'Italy_Unemployment_Rate',
#    'JOLTs_Job_Openings',
#    'Jackson_Hole_Symposium',
#    'KOF_Leading_Indicators',
#    'Manufacturing_PMI',
#    'Markit_Composite_PMI',
#    'Michigan_Consumer_Expectations',
#    'Michigan_Consumer_Sentiment',
#    'NY_Empire_State_Manufacturing_Index',
#    'Netherlands_Consumer_Confidence',
#    'Netherlands_GDP_Growth_Rate_QoQ',
#    'Netherlands_GDP_Growth_Rate_YoY',
#    'Netherlands_Inflation_Rate_MoM',
#    'Netherlands_Inflation_Rate_YoY',
#    'Netherlands_Unemployment_Rate',
#    'New_Home_Sales',
#    'Nonfarm_Payrolls',
#    'Nonfarm_Productivity',
#    'OPEC_Crude_Oil_Production_Algeria_Barrel',
#    'OPEC_Crude_Oil_Production_Congo_Barrel',
#    'OPEC_Crude_Oil_Production_Ecuador_Barrel',
#    'OPEC_Crude_Oil_Production_Gabon_Barrel',
#    'OPEC_Crude_Oil_Production_Guinea_Barrel',
#    'OPEC_Crude_Oil_Production_Kuwait_Barrel',
#    'OPEC_Crude_Oil_Production_Libya_Barrel',
#    'OPEC_Crude_Oil_Production_Nigeria_Barrel',
#    'OPEC_Crude_oil_Production_Iran_Barrel',
#    'OPEC_Crude_oil_Production_Iraq_Barrel',
#    'OPEC_Crude_oil_Production_Saudi_Arabia_Barrel',
#    'OPEC_Crude_oil_Production_UAE_Barrel',
#    'OPEC_Crude_oil_Production_Venezuela_Barrel',
#    'OPEC_Meeting',
#    'OPEC_Monthly_Report',
#    'PCE_Deflator',
#    'PCE_Price_index',
#    'PCE_price_index',
#    'PPI',
#    'Participation_Rate',
#    'Pending_Home_Sales',
#    'Personal_Spending',
#    'Philadelphia_Fed_Manufacturing_Index',
#    'Philly_Fed_Employment',
#    'Portugal_GDP_Growth_Rate_QoQ',
#    'Portugal_GDP_Growth_Rate_YoY',
#    'Presidential_Debate',
#    'Private_Nonfarm_Payrolls',
#    'Retail_Inventories_Ex_Auto',
#    'Retail_Sales',
#    'SECO_Consumer_Climate',
#    'SNB_Board_Member_Jordan_Speaks',
#    'SNB_Chairman_Hildebrand_Speaks',
#    'SNB_Chairman_Thomas_Jordan_speaks',
#    'SNB_Gov_Board_Member_Maechler_Speaks',
#    'SNB_Gov_Board_Member_Zurbrugg_Speaks',
#    'SNB_Interest_Rate_Decision',
#    'SNB_Monetary_Policy_Assessment',
#    'SNB_Press_Conference',
#    'SVME_PMI',
#    'Samp;PCS_HPI_Composite_-_20_n_s_a_',
#    'Sec_Kashkari_Speaks',
#    'Seevol_Cushing_Storage_Report',
#    'Services_PMI',
#    'Slovenia_GDP_Growth_Rate_QoQ',
#    'Slovenia_GDP_Growth_Rate_YoY',
#    'Spain_Balance_of_Trade',
#    'Spain_Business_Confidence',
#    'Spain_Consumer_Confidence',
#    'Spain_GDP_Growth_Rate_QoQ',
#    'Spain_GDP_Growth_Rate_YoY',
#    'Spain_Inflation_Rate_MoM',
#    'Spain_Inflation_Rate_YoY',
#    'Spain_Markit_Composite_PMI',
#    'Spain_Markit_Manufacturing_PMI',
#    'Spain_Markit_Services_PMI',
#    'Spain_Retail_Sales_MoM',
#    'Spain_Retail_Sales_YoY',
#    'Spain_Unemployment_Change',
#    'Spain_Unemployment_Rate',
#    'Spanish_10-Year_Obligacion_Auction',
#    'Spanish_15-Year_Obligacion_Auction',
#    'Spanish_50-Year_Obligacion_Auction',
#    'Spanish_CPI',
#    'Spanish_GDP',
#    'Spanish_General_Election',
#    'Spanish_HICP',
#    'Spanish_Manufacturing_PMI',
#    'Spanish_Services_PMI',
#    'Spanish_Unemployment_Change',
#    'TIC_Net_Long-Term_Transactions',
#    'Trade_Balance',
#    'Treasury_Department_Report',
#    'Treasury_Secretary_Geithner_Speaks',
#    'Treasury_Secretary_Lew_Speaks',
#    'Treasury_Secretary_Mnuchin_Speaks',
#    'Treasury_Secretary_Yellen_Speaks',
#    'U_S__Baker_Hughes_Oil_Rig_Count',
#    'U_S__Baker_Hughes_Total_Rig_Count',
#    'U_S__President_Biden_Speaks',
#    'U_S__President_Trump_Speaks',
#    'U_S__Presidential_Election',
#    'Unemployment_Rate',
#    'Unemployment_Rate_n_s_a_',
#    'Unemployment_Rate_s_a_',
#    'Unit_Labor_Costs',
#    'United_States_10-Year_Note_Auction',
#    'United_States_30-Year_Bond_Auction',
#    'United_States_ADP_Employment_Change',
#    'United_States_API_Crude_Oil_Stock_Change',
#    'United_States_Average_Hourly_Earnings_MoM',
#    'United_States_Average_Hourly_Earnings_YoY',
#    'United_States_Balance_of_Trade',
#    'United_States_Building_Permits',
#    'United_States_Building_Permits_MoM',
#    'United_States_Business_Inventories_MoM',
#    'United_States_CB_Consumer_Confidence',
#    'United_States_Chicago_Fed_National_Activity_Index',
#    'United_States_Chicago_PMI',
#    'United_States_Construction_Spending_MoM',
#    'United_States_Continuing_Jobless_Claims',
#    'United_States_Core_Inflation_Rate_MoM',
#    'United_States_Core_Inflation_Rate_YoY',
#    'United_States_Core_PPI_MoM',
#    'United_States_Corporate_Profits_QoQ',
#    'United_States_Current_Account',
#    'United_States_Dallas_Fed_Manufacturing_Index',
#    'United_States_Durable_Goods_Orders_Ex_Transp_MoM',
#    'United_States_Durable_Goods_Orders_MoM',
#    'United_States_Durable_Goods_Orders_ex_Defense_MoM',
#    'United_States_EIA_Crude_Oil_Stocks_Change',
#    'United_States_EIA_Cushing_Crude_Oil_Stocks_Change',
#    'United_States_EIA_Gasoline_Stocks_Change',
#    'United_States_Employment_Cost_-_Benefits_QoQ',
#    'United_States_Employment_Cost_-_Wages_QoQ',
#    'United_States_Employment_Cost_Index_QoQ',
#    'United_States_Existing_Home_Sales',
#    'United_States_Existing_Home_Sales_MoM',
#    'United_States_Export_Prices_MoM',
#    'United_States_Export_Prices_YoY',
#    'United_States_Exports',
#    'United_States_FOMC_Economic_Projections',
#    'United_States_FOMC_Minutes',
#    'United_States_Factory_Orders_MoM',
#    'United_States_Fed_Bank_Stress_Test_Results',
#    'United_States_Fed_Barkin_Speech',
#    'United_States_Fed_Barkins_Speech',
#    'United_States_Fed_Bostic_Speech',
#    'United_States_Fed_Bowman_Speech',
#    'United_States_Fed_Brainard_Speech',
#    'United_States_Fed_Brainard_Testimony',
#    'United_States_Fed_Bullard_Speech',
#    'United_States_Fed_Chair_Powell_Speech',
#    'United_States_Fed_Chair_Powell_Testimony',
#    'United_States_Fed_Chair_Yellen_Speech',
#    'United_States_Fed_Clarida_Speech',
#    'United_States_Fed_Daly_Speech',
#    'United_States_Fed_Evans_Speech',
#    'United_States_Fed_George_Speech',
#    'United_States_Fed_Harker_Speech',
#    'United_States_Fed_Interest_Rate_Decision',
#    'United_States_Fed_Kaplan_Speech',
#    'United_States_Fed_Kashkari_Speech',
#    'United_States_Fed_Mester_Speech',
#    'United_States_Fed_Monetary_Policy_Report',
#    'United_States_Fed_Press_Conference',
#    'United_States_Fed_Quarles_Speech',
#    'United_States_Fed_Quarles_Testimony',
#    'United_States_Fed_Quarterly_Financial_Accounts',
#    'United_States_Fed_Rosengren_Speech',
#    'United_States_Fed_Waller_Speech',
#    'United_States_Fed_Williams_Speech',
#    'United_States_Foreign_Bond_Investment',
#    'United_States_GDP_Growth_Rate_QoQ',
#    'United_States_GDP_Price_Index_QoQ',
#    'United_States_Goods_Trade_Balance',
#    'United_States_Housing_Starts',
#    'United_States_Housing_Starts_MoM',
#    'United_States_IBDTIPP_Economic_Optimism',
#    'United_States_IMFWorld_Economic_Outlook',
#    'United_States_ISM_Manufacturing_PMI',
#    'United_States_ISM_Non-Manufacturing_PMI',
#    'United_States_Import_Prices_MoM',
#    'United_States_Import_Prices_YoY',
#    'United_States_Imports',
#    'United_States_Industrial_Production_MoM',
#    'United_States_Industrial_Production_YoY',
#    'United_States_Inflation_Rate_MoM',
#    'United_States_Inflation_Rate_YoY',
#    'United_States_Initial_Jobless_Claims',
#    'United_States_Interest_Rate_Projection_-_1st_Yr',
#    'United_States_Interest_Rate_Projection_-_2nd_Yr',
#    'United_States_Interest_Rate_Projection_-_3rd_Yr',
#    'United_States_Interest_Rate_Projection_-_Current',
#    'United_States_Interest_Rate_Projection_-_Longer',
#    'United_States_JOLTs_Job_Openings',
#    'United_States_Jackson_Hole_Economic_Symposium',
#    'United_States_Jobless_Claims_4-week_Average',
#    'United_States_Markit_Composite_PMI',
#    'United_States_Markit_Manufacturing_PMI',
#    'United_States_Markit_Services_PMI',
#    'United_States_Michigan_5_Year_Inflation_Expectations',
#    'United_States_Michigan_Consumer_Expectations',
#    'United_States_Michigan_Consumer_Sentiment',
#    'United_States_Michigan_Current_Conditions',
#    'United_States_Michigan_Inflation_Expectations',
#    'United_States_Monthly_Budget_Statement',
#    'United_States_NAHB_Housing_Market_Index',
#    'United_States_NY_Empire_State_Manufacturing_Index',
#    'United_States_Net_Long-Term_Tic_Flows',
#    'United_States_Net_Long-term_TIC_Flows',
#    'United_States_New_Home_Sales',
#    'United_States_New_Home_Sales_MoM',
#    'United_States_Non_Farm_Payrolls',
#    'United_States_Nonfarm_Payrolls_Private',
#    'United_States_Nonfarm_Productivity_QoQ',
#    'United_States_Overall_Net_Capital_Flows',
#    'United_States_PCE_Price_Index_MoM',
#    'United_States_PCE_Price_Index_YoY',
#    'United_States_PPI_MoM',
#    'United_States_Participation_Rate',
#    'United_States_Pending_Home_Sales_MoM',
#    'United_States_Pending_Home_Sales_YoY',
#    'United_States_Personal_Income_MoM',
#    'United_States_Personal_Spending_MoM',
#    'United_States_Philadelphia_Fed_Manufacturing_Index',
#    'United_States_President_Biden_2023_Budget_Speech',
#    'United_States_President_Biden_Remarks_on_the_Economy',
#    'United_States_President_Biden_Speech',
#    'United_States_President_Biden_State_of_the_Union_Speech',
#    'United_States_President_Biden_and_President_Xi_Virtual_Meeting',
#    'United_States_Presidents_FY2022_Budget',
#    'United_States_Retail_Inventories_Ex_Autos_MoM',
#    'United_States_Retail_Sales_Ex_Autos_MoM',
#    'United_States_Retail_Sales_Ex_GasAutos_MoM',
#    'United_States_Retail_Sales_MoM',
#    'United_States_Retail_Sales_YoY',
#    'United_States_SPCase-Shiller_Home_Price_MoM',
#    'United_States_SPCase-Shiller_Home_Price_YoY',
#    'United_States_Total_Vehicle_Sales',
#    'United_States_Treasury_Secretary_Yellen_Speech',
#    'United_States_Treasury_Secretary_Yellen_Testimony',
#    'United_States_Unemployment_Rate',
#    'United_States_Unit_Labour_Costs_QoQ',
#    'United_States_Wholesale_Inventories_MoM',
#    'WASDE_Report',
#    'Wages_in_euro_zone',
#    'World_Economic_Forum_Annual_Meetings',
#    'ZEW_Economic_Sentiment',
#    'procure_ch_PMI']},
#  'constant_fill_strategy': {},
#  'allow_missing_timesteps': True,
#  'lags': {},
#  'add_relative_time_idx': False,
#  'add_target_scales': True,
#  'add_encoder_length': True,
#  'target_normalizer': GroupNormalizer(groups=['grp'], transformation='softplus'),
#  'categorical_encoders': {'__group_id__grp': NaNLabelEncoder(),
#   'grp': NaNLabelEncoder(),
#   'special_days': NaNLabelEncoder(),
#   'day_of_week': NaNLabelEncoder()},
#  'scalers': {'encoder_length': StandardScaler(),
#   'CLOSE_center': StandardScaler(),
#   'CLOSE_scale': StandardScaler(),
#   'time_idx': StandardScaler(),
#   'OPEN': StandardScaler(),
#   'HIGH': StandardScaler(),
#   'LOW': StandardScaler(),
#   'TICKVOL': StandardScaler(),
#   'VOL': StandardScaler()},
#  'randomize_length': None,
#  'predict_mode': False}

# %%
 timeseries.index
# Out:
#        time_first  time_last  time_diff_to_next  index_start  time  count  \
# 0               0      62001                  1            0     0  62002
# 1               0      62001                  1            1     1  62002
# 2               0      62001                  1            2     2  62002
# 3               0      62001                  1            3     3  62002
# 4               0      62001                  1            4     4  62002
# ...           ...        ...                ...          ...   ...    ...
# 62059           0      62001                  1            0     0  62002
# 62060           0      62001                  1            0     0  62002
# 62061           0      62001                  1            0     0  62002
# 62062           0      62001                  1            0     0  62002
# 62063           0      62001                  1            0     0  62002
#
#        group_id  index_end  sequence_length
# 0             0         74               75
# 1             0         75               75
# 2             0         76               75
# 3             0         77               75
# 4             0         78               75
# ...         ...        ...              ...
# 62059         0         69               70
# 62060         0         70               71
# 62061         0         71               72
# 62062         0         72               73
# 62063         0         73               74
#
# [62052 rows x 9 columns]

# %% [markdown]
# ### Creating Training and Validation dataloaders

# %%
validation = TimeSeriesDataSet.from_dataset(timeseries, new_df, predict = True, stop_randomization = True)

batch_size = 128
training_dataloader = timeseries.to_dataloader(train=True, batch_size = batch_size, num_workers=0)
val_dataloader = validation.to_dataloader(train=False, batch_size = batch_size*100, num_workers=0)

# %%
x, y = next(iter(training_dataloader))
# print("x =", x)
# print("\ny =", y)
# print("\nsizes of x =")
for key, value in x.items():
    print(f"\t{key} = {value.size()}")
# Out:
# 	encoder_cat = torch.Size([128, 25, 559])
# 	encoder_cont = torch.Size([128, 25, 10])
# 	encoder_target = torch.Size([128, 25])
# 	encoder_lengths = torch.Size([128])
# 	decoder_cat = torch.Size([128, 50, 559])
# 	decoder_cont = torch.Size([128, 50, 10])
# 	decoder_target = torch.Size([128, 50])
# 	decoder_lengths = torch.Size([128])
# 	decoder_time_idx = torch.Size([128, 50])
# 	groups = torch.Size([128, 1])
# 	target_scale = torch.Size([128, 2])

# %% [markdown]
# ### Baseline Model Prediction

# %%
import torch

from pytorch_forecasting import Baseline, TemporalFusionTransformer

actuals = torch.cat([y for x, (y, weight) in iter(val_dataloader)])
baseline_predictions = Baseline().predict(val_dataloader)
torch.Tensor.float(actuals - baseline_predictions).abs().mean().item()
# Out:
# 0.0026237773708999157

# %% [markdown]
# ### Finding Optimal Learning Rate

# %%
import pytorch_lightning as pl
from pytorch_forecasting.metrics import SMAPE, PoissonLoss, QuantileLoss
from pytorch_forecasting.models.temporal_fusion_transformer.tuning import optimize_hyperparameters

# pl.seed_everything(42)
trainer = pl.Trainer(
gpus=1,  
)

tft = TemporalFusionTransformer.from_dataset(
timeseries,
learning_rate = 0.03,
hidden_size=16,
attention_head_size=1,
dropout=0.1,
hidden_continuous_size=8,
output_size=7,
loss=QuantileLoss(),
reduce_on_plateau_patience=4,
)

print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 31.0k

# %%
res = trainer.tuner.lr_find(
tft,
train_dataloaders=training_dataloader,
    val_dataloaders = val_dataloader,
    max_lr = 10.0,
    min_lr=1e-6,
)


print(f"suggested learning rate: {res.suggestion()}")
fig = res.plot(show=True, suggest=True)
fig.show()
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Finding best initial lr:   0%|          | 0/100 [00:00<?, ?it/s]
# Restoring states from the checkpoint path at D:\AIT\2nd Sem\RTML\Group\Forex-Prediction\.lr_find_50e20277-3a21-453b-aa0e-69b3ab293527.ckpt
# suggested learning rate: 0.5495408738576241

# %% [markdown]
# ### Training TFT model

# %%
early_stop_callback = EarlyStopping(monitor="val_loss", min_delta=1e-4, patience=10, verbose=False, mode="min")
lr_logger = LearningRateMonitor()  # log the learning rate
logger = TensorBoardLogger("lightning_logs")  # logging results to a tensorboard

trainer = pl.Trainer(
    max_epochs=10,
    gpus=1,
    weights_summary="top",
    gradient_clip_val=0.1,
    limit_train_batches=30,  # coment in for training, running valiation every 30 batches
    # fast_dev_run=True,  # comment in to check that networkor dataset has no serious bugs
    callbacks=[lr_logger, early_stop_callback],
    logger=logger,
)


tft = TemporalFusionTransformer.from_dataset(
timeseries,
learning_rate = 0.03,
hidden_size=16,
attention_head_size=1,
dropout=0.1,
hidden_continuous_size=8,
output_size=7,
loss=QuantileLoss(),
reduce_on_plateau_patience=4,
)

print(f"Number of parameters in network: {tft.size()/1e3:.1f}k")
# Out:
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# HPU available: False, using: 0 HPUs
# Number of parameters in network: 31.0k

# %%
trainer.fit(
    tft,
    train_dataloaders=training_dataloader,
    val_dataloaders=val_dataloader,
)
# Out:
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
#
#    | Name                               | Type                            | Params
# ----------------------------------------------------------------------------------------
# 0  | loss                               | QuantileLoss                    | 0
# 1  | logging_metrics                    | ModuleList                      | 0
# 2  | input_embeddings                   | MultiEmbedding                  | 5.9 K
# 3  | prescalers                         | ModuleDict                      | 160
# 4  | static_variable_selection          | VariableSelectionNetwork        | 1.8 K
# 5  | encoder_variable_selection         | VariableSelectionNetwork        | 4.9 K
# 6  | decoder_variable_selection         | VariableSelectionNetwork        | 4.2 K
# 7  | static_context_variable_selection  | GatedResidualNetwork            | 1.1 K
# 8  | static_context_initial_hidden_lstm | GatedResidualNetwork            | 1.1 K
# 9  | static_context_initial_cell_lstm   | GatedResidualNetwork            | 1.1 K
# 10 | static_context_enrichment          | GatedResidualNetwork            | 1.1 K
# 11 | lstm_encoder                       | LSTM                            | 2.2 K
# 12 | lstm_decoder                       | LSTM                            | 2.2 K
# 13 | post_lstm_gate_encoder             | GatedLinearUnit                 | 544
# 14 | post_lstm_add_norm_encoder         | AddNorm                         | 32
# 15 | static_enrichment                  | GatedResidualNetwork            | 1.4 K
# 16 | multihead_attn                     | InterpretableMultiHeadAttention | 1.1 K
# 17 | post_attn_gate_norm                | GateAddNorm                     | 576
# 18 | pos_wise_ff                        | GatedResidualNetwork            | 1.1 K
# 19 | pre_output_gate_norm               | GateAddNorm                     | 576
# 20 | output_layer                       | Linear                          | 119
# ----------------------------------------------------------------------------------------
# 31.0 K    Trainable params
# 0         Non-trainable params
# 31.0 K    Total params
# 0.124     Total estimated model params size (MB)
# Sanity Checking: 0it [00:00, ?it/s]
# Training: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]
# Validation: 0it [00:00, ?it/s]

# %% [markdown]
# #### Loading the model from checkpoint

# %%
best_model_path = trainer.checkpoint_callback.best_model_path
best_tft = TemporalFusionTransformer.load_from_checkpoint(best_model_path)

# %%
# raw predictions are a dictionary from which all kind of information including quantiles can be extracted
raw_predictions, x = best_tft.predict(val_dataloader, mode="raw", return_x=True)

# %% [markdown]
# #### Plotting Prediction

# %%
best_tft.plot_prediction(x, raw_predictions, idx=0, add_loss_to_title=True);

# %% [markdown]
# ### Interpretation Analysis

# %%
interpretation = best_tft.interpret_output(raw_predictions, reduction="sum")
best_tft.plot_interpretation(interpretation)
# Out:
# {'attention': <Figure size 432x288 with 1 Axes>,
#  'static_variables': <Figure size 504x216 with 1 Axes>,
#  'encoder_variables': <Figure size 504x306 with 1 Axes>,
#  'decoder_variables': <Figure size 504x288 with 1 Axes>}
